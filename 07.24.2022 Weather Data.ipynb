# %%
import numpy as np
import pandas as pd
import altair as alt
import requests

# %%
url = "https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00013881&startdate=2022-01-01&enddate=2022-05-01&limit=1000"

my_headers = {'token' : 'glJnMBDIsdlBWdMmFZLZikLNRhByqyia'}


r = requests.get(url,headers=my_headers)

# print(r)

json = r.json()

# json

# %%
json.keys()
# Out:
# dict_keys(['metadata', 'results'])

# %%
type(json['results'][0])
# Out:
# dict

# %%
json['metadata']
# Out:
# {'resultset': {'offset': 1, 'count': 2241, 'limit': 1000}}

# %%
df = pd.DataFrame(json['results'])
df[0:25]
# Out:
#                    date datatype            station attributes  value
# 0   2022-01-01T00:00:00     ADPT  GHCND:USW00013881       ,,W,    183
# 1   2022-01-01T00:00:00     ASLP  GHCND:USW00013881       ,,W,  10098
# 2   2022-01-01T00:00:00     ASTP  GHCND:USW00013881       ,,W,   9834
# 3   2022-01-01T00:00:00     AWBT  GHCND:USW00013881       ,,W,    189
# 4   2022-01-01T00:00:00     AWND  GHCND:USW00013881       ,,W,     60
# 5   2022-01-01T00:00:00     PRCP  GHCND:USW00013881   ,,W,2400     33
# 6   2022-01-01T00:00:00     RHAV  GHCND:USW00013881       ,,W,     97
# 7   2022-01-01T00:00:00     RHMN  GHCND:USW00013881       ,,W,     84
# 8   2022-01-01T00:00:00     RHMX  GHCND:USW00013881       ,,W,     67
# 9   2022-01-01T00:00:00     SNOW  GHCND:USW00013881       ,,W,      0
# 10  2022-01-01T00:00:00     SNWD  GHCND:USW00013881   ,,W,2400      0
# 11  2022-01-01T00:00:00     TAVG  GHCND:USW00013881      H,,S,    205
# ...

# %%
set(df['datatype'])
# Out:
# {'ADPT',
#  'ASLP',
#  'ASTP',
#  'AWBT',
#  'AWND',
#  'PRCP',
#  'RHAV',
#  'RHMN',
#  'RHMX',
#  'SNOW',
#  'SNWD',
#  'TAVG',
#  'TMAX',
#  'TMIN',
#  'WDF2',
#  'WDF5',
#  'WSF2',
#  'WSF5',
#  'WT01',
#  'WT02',
#  'WT04',
#  'WT06',
#  'WT08'}

# %%
df_temp=df[df['datatype']=='TMAX']
df_temp['value']=df_temp['value']/10
df_temp['F']=df_temp['value']*9/5+32


df_temp[0:25]
# Out:
# C:\Users\Dmitry\AppData\Local\Temp\ipykernel_36332\3519221432.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp['value']=df_temp['value']/10
# C:\Users\Dmitry\AppData\Local\Temp\ipykernel_36332\3519221432.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp['F']=df_temp['value']*9/5+32
#                     date datatype            station attributes  value      F
# 12   2022-01-01T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   25.6  78.08
# ...

# %%
alt.Chart(df_temp).mark_line().encode(
    x='date',
    y='F'
)
# Out:
# alt.Chart(...)
