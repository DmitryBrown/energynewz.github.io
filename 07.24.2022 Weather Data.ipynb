# %%
import numpy as np
import pandas as pd
import altair as alt
import requests
# Out:
#   Input In [54]
#     https://docs.opendata.aws/noaa-ghcn-pds/readme.html#:~:text=SNWD%20%3D%20Snow%20depth%20(mm),temperature%20(tenths%20of%20degrees%20C)
#           ^
# SyntaxError: invalid syntax

# %%
url = "https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00013881&startdate=2022-01-01&enddate=2022-05-01&limit=1000"

my_headers = {'token' : 'glJnMBDIsdlBWdMmFZLZikLNRhByqyia'}


r = requests.get(url,headers=my_headers)

print(r)

json = r.json()

# json
# Out:
# <Response [200]>
# {'metadata': {'resultset': {'offset': 1, 'count': 2241, 'limit': 1000}},
#  'results': [{'date': '2022-01-01T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 183},
#   {'date': '2022-01-01T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10098},
#   {'date': '2022-01-01T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9834},
#   {'date': '2022-01-01T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 189},
#   {'date': '2022-01-01T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 60},
#   {'date': '2022-01-01T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 33},
#   {'date': '2022-01-01T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 97},
#   {'date': '2022-01-01T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 84},
#   {'date': '2022-01-01T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 67},
#   {'date': '2022-01-01T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-01-01T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 205},
#   {'date': '2022-01-01T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 256},
#   {'date': '2022-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 183},
#   {'date': '2022-01-01T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 200},
#   {'date': '2022-01-01T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 200},
#   {'date': '2022-01-01T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 116},
#   {'date': '2022-01-01T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 165},
#   {'date': '2022-01-01T00:00:00',
#    'datatype': 'WT01',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 1},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 161},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10088},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9814},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 172},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 51},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 127},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 97},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 88},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 73},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 198},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 217},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 150},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 210},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 210},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 143},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 179},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'WT01',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 1},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 33},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10149},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9848},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 56},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 61},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 455},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 97},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 76},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 48},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 107},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 150},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': -10},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 20},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 161},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 210},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'WT01',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 1},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': -56},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10281},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9997},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 30},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 78},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 55},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 35},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 27},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 78},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': -21},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 110},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 100},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 58},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 94},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10163},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9892},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 50},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 26},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 74},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 57},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 38},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 76},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 156},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 33},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 220},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 210},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 76},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 98},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 11},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10119},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9848},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 56},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 34},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'T,,W,2400',
#    'value': 0},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 93},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 59},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 26},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 88},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 167},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 11},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 210},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 210},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 94},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 139},
#   {'date': '2022-01-07T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': -83},
#   {'date': '2022-01-07T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10213},
#   {'date': '2022-01-07T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9912},
#   {'date': '2022-01-07T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': -11},
#   {'date': '2022-01-07T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 33},
#   {'date': '2022-01-07T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-07T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 66},
#   {'date': '2022-01-07T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 45},
#   {'date': '2022-01-07T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 25},
#   {'date': '2022-01-07T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-01-07T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-07T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 57},
#   {'date': '2022-01-07T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 94},
#   {'date': '2022-01-07T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': -10},
#   {'date': '2022-01-07T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 300},
#   {'date': '2022-01-07T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 300},
#   {'date': '2022-01-07T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 89},
#   {'date': '2022-01-07T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 116},
#   {'date': '2022-01-08T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': -106},
#   {'date': '2022-01-08T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10349},
#   {'date': '2022-01-08T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10051},
#   {'date': '2022-01-08T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': -22},
#   {'date': '2022-01-08T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 27},
#   {'date': '2022-01-08T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-08T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 55},
#   {'date': '2022-01-08T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 41},
#   {'date': '2022-01-08T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 27},
#   {'date': '2022-01-08T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-01-08T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-08T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 6},
#   {'date': '2022-01-08T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 67},
#   {'date': '2022-01-08T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': -32},
#   {'date': '2022-01-08T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 70},
#   {'date': '2022-01-08T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 80},
#   {'date': '2022-01-08T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 54},
#   {'date': '2022-01-08T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 89},
#   {'date': '2022-01-09T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 28},
#   {'date': '2022-01-09T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10264},
#   {'date': '2022-01-09T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9997},
#   {'date': '2022-01-09T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 67},
#   {'date': '2022-01-09T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 22},
#   {'date': '2022-01-09T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 94},
#   {'date': '2022-01-09T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 100},
#   {'date': '2022-01-09T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 67},
#   {'date': '2022-01-09T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 43},
#   {'date': '2022-01-09T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-01-09T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-09T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 81},
#   {'date': '2022-01-09T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 150},
#   {'date': '2022-01-09T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 50},
#   {'date': '2022-01-09T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 320},
#   {'date': '2022-01-09T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 330},
#   {'date': '2022-01-09T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 89},
#   {'date': '2022-01-09T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 116},
#   {'date': '2022-01-09T00:00:00',
#    'datatype': 'WT01',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 1},
#   {'date': '2022-01-10T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': -72},
#   {'date': '2022-01-10T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10257},
#   {'date': '2022-01-10T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9970},
#   {'date': '2022-01-10T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 17},
#   {'date': '2022-01-10T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 38},
#   {'date': '2022-01-10T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-10T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 89},
#   {'date': '2022-01-10T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 36},
#   {'date': '2022-01-10T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 20},
#   {'date': '2022-01-10T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-01-10T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-10T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 86},
#   {'date': '2022-01-10T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 111},
#   {'date': '2022-01-10T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 22},
#   {'date': '2022-01-10T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 360},
#   {'date': '2022-01-10T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 360},
#   {'date': '2022-01-10T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 89},
#   {'date': '2022-01-10T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 112},
#   {'date': '2022-01-11T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': -117},
#   {'date': '2022-01-11T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10318},
#   {'date': '2022-01-11T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10027},
#   {'date': '2022-01-11T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': -17},
#   {'date': '2022-01-11T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 28},
#   {'date': '2022-01-11T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-11T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 54},
#   {'date': '2022-01-11T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 35},
#   {'date': '2022-01-11T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 18},
#   {'date': '2022-01-11T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-01-11T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-11T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 35},
#   {'date': '2022-01-11T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 83},
#   {'date': '2022-01-11T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': -32},
#   {'date': '2022-01-11T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 350},
#   {'date': '2022-01-11T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 360},
#   {'date': '2022-01-11T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 72},
#   {'date': '2022-01-11T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 89},
#   {'date': '2022-01-12T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': -83},
#   {'date': '2022-01-12T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10261},
#   {'date': '2022-01-12T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9986},
#   {'date': '2022-01-12T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': -6},
#   {'date': '2022-01-12T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 21},
#   {'date': '2022-01-12T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-12T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 63},
#   {'date': '2022-01-12T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 43},
#   {'date': '2022-01-12T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 26},
#   {'date': '2022-01-12T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-01-12T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-12T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 32},
#   {'date': '2022-01-12T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 111},
#   {'date': '2022-01-12T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': -49},
#   {'date': '2022-01-12T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 230},
#   {'date': '2022-01-12T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 230},
#   {'date': '2022-01-12T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 67},
#   {'date': '2022-01-12T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 81},
#   {'date': '2022-01-13T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': -28},
#   {'date': '2022-01-13T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10135},
#   {'date': '2022-01-13T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9865},
#   {'date': '2022-01-13T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 17},
#   {'date': '2022-01-13T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10},
#   {'date': '2022-01-13T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-13T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 82},
#   {'date': '2022-01-13T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 59},
#   {'date': '2022-01-13T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 38},
#   {'date': '2022-01-13T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-01-13T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-13T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 48},
#   {'date': '2022-01-13T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 122},
#   {'date': '2022-01-13T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': -27},
#   {'date': '2022-01-13T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 340},
#   {'date': '2022-01-13T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 140},
#   {'date': '2022-01-13T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 31},
#   {'date': '2022-01-13T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 54},
#   {'date': '2022-01-14T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': -11},
#   {'date': '2022-01-14T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10132},
#   {'date': '2022-01-14T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9844},
#   {'date': '2022-01-14T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 33},
#   {'date': '2022-01-14T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 29},
#   {'date': '2022-01-14T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-14T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 88},
#   {'date': '2022-01-14T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 58},
#   {'date': '2022-01-14T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 36},
#   {'date': '2022-01-14T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-01-14T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-14T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 70},
#   {'date': '2022-01-14T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 150},
#   {'date': '2022-01-14T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': -10},
#   {'date': '2022-01-14T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 360},
#   {'date': '2022-01-14T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 340},
#   {'date': '2022-01-14T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 72},
#   {'date': '2022-01-14T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 98},
#   {'date': '2022-01-15T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': -28},
#   {'date': '2022-01-15T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10210},
#   {'date': '2022-01-15T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9919},
#   {'date': '2022-01-15T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 11},
#   {'date': '2022-01-15T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 34},
#   {'date': '2022-01-15T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-15T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 73},
#   {'date': '2022-01-15T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 60},
#   {'date': '2022-01-15T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 53},
#   {'date': '2022-01-15T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-01-15T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-15T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 44},
#   {'date': '2022-01-15T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 67},
#   {'date': '2022-01-15T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': -5},
#   {'date': '2022-01-15T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 80},
#   {'date': '2022-01-15T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 90},
#   {'date': '2022-01-15T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 67},
#   {'date': '2022-01-15T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 116},
#   {'date': '2022-01-16T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': -33},
#   {'date': '2022-01-16T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10081},
#   {'date': '2022-01-16T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9790},
#   {'date': '2022-01-16T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': -17},
#   {'date': '2022-01-16T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 52},
#   {'date': '2022-01-16T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 249},
#   {'date': '2022-01-16T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 96},
#   {'date': '2022-01-16T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 86},
#   {'date': '2022-01-16T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 57},
#   {'date': '2022-01-16T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 56},
#   {'date': '2022-01-16T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 30},
#   {'date': '2022-01-16T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 4},
#   {'date': '2022-01-16T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 33},
#   {'date': '2022-01-16T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': -32},
#   {'date': '2022-01-16T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 50},
#   {'date': '2022-01-16T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 50},
#   {'date': '2022-01-16T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 107},
#   {'date': '2022-01-16T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 148},
#   {'date': '2022-01-16T00:00:00',
#    'datatype': 'WT01',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 1},
#   {'date': '2022-01-16T00:00:00',
#    'datatype': 'WT04',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 1},
#   {'date': '2022-01-16T00:00:00',
#    'datatype': 'WT06',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 1},
#   {'date': '2022-01-17T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': -39},
#   {'date': '2022-01-17T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10054},
#   {'date': '2022-01-17T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9760},
#   {'date': '2022-01-17T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-01-17T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 48},
#   {'date': '2022-01-17T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-17T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 92},
#   {'date': '2022-01-17T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 67},
#   {'date': '2022-01-17T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 41},
#   {'date': '2022-01-17T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-01-17T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 30},
#   {'date': '2022-01-17T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 13},
#   {'date': '2022-01-17T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 61},
#   {'date': '2022-01-17T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': -10},
#   {'date': '2022-01-17T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 230},
#   {'date': '2022-01-17T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 240},
#   {'date': '2022-01-17T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 89},
#   {'date': '2022-01-17T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 121},
#   {'date': '2022-01-18T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': -56},
#   {'date': '2022-01-18T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10207},
#   {'date': '2022-01-18T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9909},
#   {'date': '2022-01-18T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': -6},
#   {'date': '2022-01-18T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 13},
#   {'date': '2022-01-18T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-18T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 88},
#   {'date': '2022-01-18T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 58},
#   {'date': '2022-01-18T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 31},
#   {'date': '2022-01-18T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-01-18T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'T,,W,2400',
#    'value': 0},
#   {'date': '2022-01-18T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 18},
#   {'date': '2022-01-18T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 100},
#   {'date': '2022-01-18T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': -66},
#   {'date': '2022-01-18T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 350},
#   {'date': '2022-01-18T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 350},
#   {'date': '2022-01-18T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 54},
#   {'date': '2022-01-18T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 67},
#   {'date': '2022-01-19T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': -17},
#   {'date': '2022-01-19T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10220},
#   {'date': '2022-01-19T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9939},
#   {'date': '2022-01-19T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 33},
#   {'date': '2022-01-19T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 33},
#   {'date': '2022-01-19T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-01-19T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 76},
#   {'date': '2022-01-19T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 55},
#   {'date': '2022-01-19T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 33},
#   {'date': '2022-01-19T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-01-19T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'T,,W,2400',
#    'value': 0},
#   {'date': '2022-01-19T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 58},
#   {'date': '2022-01-19T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 150},
#   {'date': '2022-01-19T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': -16},
#   {'date': '2022-01-19T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 200},
#   {'date': '2022-01-19T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 180},
#   {'date': '2022-01-19T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 67},
#   {'date': '2022-01-19T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 94},
#   {'date': '2022-01-20T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 28},
#   {'date': '2022-01-20T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10200},
#   {'date': '2022-01-20T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9909},
#   {'date': '2022-01-20T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 50},
#   {'date': '2022-01-20T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
# ...
#    'value': 190},
#   {'date': '2022-02-17T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 134},
#   {'date': '2022-02-17T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 179},
#   {'date': '2022-02-17T00:00:00',
#    'datatype': 'WT01',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 1},
#   {'date': '2022-02-17T00:00:00',
#    'datatype': 'WT02',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 1},
#   {'date': '2022-02-18T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 61},
#   {'date': '2022-02-18T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10135},
#   {'date': '2022-02-18T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9848},
#   {'date': '2022-02-18T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 106},
#   {'date': '2022-02-18T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 51},
#   {'date': '2022-02-18T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 135},
#   {'date': '2022-02-18T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 93},
#   {'date': '2022-02-18T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 61},
#   {'date': '2022-02-18T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 34},
#   {'date': '2022-02-18T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-02-18T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-02-18T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 176},
#   {'date': '2022-02-18T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 211},
#   {'date': '2022-02-18T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 33},
#   {'date': '2022-02-18T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 200},
#   {'date': '2022-02-18T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 180},
#   {'date': '2022-02-18T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 179},
#   {'date': '2022-02-18T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 233},
#   {'date': '2022-02-18T00:00:00',
#    'datatype': 'WT01',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 1},
#   {'date': '2022-02-19T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': -67},
#   {'date': '2022-02-19T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10230},
#   {'date': '2022-02-19T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9949},
#   {'date': '2022-02-19T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 17},
#   {'date': '2022-02-19T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 34},
#   {'date': '2022-02-19T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-02-19T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 81},
#   {'date': '2022-02-19T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 42},
#   {'date': '2022-02-19T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 18},
#   {'date': '2022-02-19T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-02-19T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-02-19T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 69},
#   {'date': '2022-02-19T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 161},
#   {'date': '2022-02-19T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': -32},
#   {'date': '2022-02-19T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 320},
#   {'date': '2022-02-19T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 340},
#   {'date': '2022-02-19T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 89},
#   {'date': '2022-02-19T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 125},
#   {'date': '2022-02-20T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': -111},
#   {'date': '2022-02-20T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10298},
#   {'date': '2022-02-20T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10014},
#   {'date': '2022-02-20T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 6},
#   {'date': '2022-02-20T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 21},
#   {'date': '2022-02-20T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-02-20T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 49},
#   {'date': '2022-02-20T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 29},
#   {'date': '2022-02-20T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 15},
#   {'date': '2022-02-20T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-02-20T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-02-20T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 61},
#   {'date': '2022-02-20T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 128},
#   {'date': '2022-02-20T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': -38},
#   {'date': '2022-02-20T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 20},
#   {'date': '2022-02-20T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 120},
#   {'date': '2022-02-20T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 58},
#   {'date': '2022-02-20T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 94},
#   {'date': '2022-02-21T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 50},
#   {'date': '2022-02-21T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10271},
#   {'date': '2022-02-21T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9993},
#   {'date': '2022-02-21T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 78},
#   {'date': '2022-02-21T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 8},
#   {'date': '2022-02-21T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-02-21T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 83},
#   {'date': '2022-02-21T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 68},
#   {'date': '2022-02-21T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 47},
#   {'date': '2022-02-21T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-02-21T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-02-21T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 91},
#   {'date': '2022-02-21T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 172},
#   {'date': '2022-02-21T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 6},
#   {'date': '2022-02-21T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 160},
#   {'date': '2022-02-21T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 160},
#   {'date': '2022-02-21T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 45},
#   {'date': '2022-02-21T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 54},
#   {'date': '2022-02-21T00:00:00',
#    'datatype': 'WT08',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 1},
#   {'date': '2022-02-22T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 128},
#   {'date': '2022-02-22T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10237},
#   {'date': '2022-02-22T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9963},
#   {'date': '2022-02-22T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 144},
#   {'date': '2022-02-22T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 42},
#   {'date': '2022-02-22T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'T,,W,2400',
#    'value': 0},
#   {'date': '2022-02-22T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 90},
#   {'date': '2022-02-22T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 75},
#   {'date': '2022-02-22T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 57},
#   {'date': '2022-02-22T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-02-22T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-02-22T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 162},
#   {'date': '2022-02-22T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 233},
#   {'date': '2022-02-22T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 111},
#   {'date': '2022-02-22T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 190},
#   {'date': '2022-02-22T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 180},
#   {'date': '2022-02-22T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 103},
#   {'date': '2022-02-22T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 134},
#   {'date': '2022-02-23T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 144},
#   {'date': '2022-02-23T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10217},
#   {'date': '2022-02-23T00:00:00',
#    'datatype': 'ASTP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 9942},
#   {'date': '2022-02-23T00:00:00',
#    'datatype': 'AWBT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 150},
#   {'date': '2022-02-23T00:00:00',
#    'datatype': 'AWND',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 25},
#   {'date': '2022-02-23T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 135},
#   {'date': '2022-02-23T00:00:00',
#    'datatype': 'RHAV',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 97},
#   {'date': '2022-02-23T00:00:00',
#    'datatype': 'RHMN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 90},
#   {'date': '2022-02-23T00:00:00',
#    'datatype': 'RHMX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 80},
#   {'date': '2022-02-23T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 0},
#   {'date': '2022-02-23T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 0},
#   {'date': '2022-02-23T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00013881',
#    'attributes': 'H,,S,',
#    'value': 173},
#   {'date': '2022-02-23T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 183},
#   {'date': '2022-02-23T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,2400',
#    'value': 111},
#   {'date': '2022-02-23T00:00:00',
#    'datatype': 'WDF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 170},
#   {'date': '2022-02-23T00:00:00',
#    'datatype': 'WDF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 170},
#   {'date': '2022-02-23T00:00:00',
#    'datatype': 'WSF2',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 76},
#   {'date': '2022-02-23T00:00:00',
#    'datatype': 'WSF5',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 89},
#   {'date': '2022-02-23T00:00:00',
#    'datatype': 'WT01',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 1},
#   {'date': '2022-02-23T00:00:00',
#    'datatype': 'WT02',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 1},
#   {'date': '2022-02-24T00:00:00',
#    'datatype': 'ADPT',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 117},
#   {'date': '2022-02-24T00:00:00',
#    'datatype': 'ASLP',
#    'station': 'GHCND:USW00013881',
#    'attributes': ',,W,',
#    'value': 10230}]}

# %%
json.keys()
# Out:
# dict_keys(['metadata', 'results'])

# %%
type(json['results'][0])
# Out:
# dict

# %%
json['metadata']
# Out:
# {'resultset': {'offset': 1, 'count': 206, 'limit': 25}}

# %%
df = pd.DataFrame(json['results'])
df
# Out:
#                     date datatype            station attributes  value
# 0    2022-01-01T00:00:00     ADPT  GHCND:USW00013881       ,,W,    183
# 1    2022-01-01T00:00:00     ASLP  GHCND:USW00013881       ,,W,  10098
# 2    2022-01-01T00:00:00     ASTP  GHCND:USW00013881       ,,W,   9834
# 3    2022-01-01T00:00:00     AWBT  GHCND:USW00013881       ,,W,    189
# 4    2022-01-01T00:00:00     AWND  GHCND:USW00013881       ,,W,     60
# ..                   ...      ...                ...        ...    ...
# 995  2022-02-23T00:00:00     WSF5  GHCND:USW00013881       ,,W,     89
# 996  2022-02-23T00:00:00     WT01  GHCND:USW00013881       ,,W,      1
# 997  2022-02-23T00:00:00     WT02  GHCND:USW00013881       ,,W,      1
# 998  2022-02-24T00:00:00     ADPT  GHCND:USW00013881       ,,W,    117
# 999  2022-02-24T00:00:00     ASLP  GHCND:USW00013881       ,,W,  10230
#
# [1000 rows x 5 columns]

# %%
set(df['datatype'])
# Out:
# {'ADPT',
#  'ASLP',
#  'ASTP',
#  'AWBT',
#  'AWND',
#  'PRCP',
#  'RHAV',
#  'RHMN',
#  'RHMX',
#  'SNOW',
#  'SNWD',
#  'TAVG',
#  'TMAX',
#  'TMIN',
#  'WDF2',
#  'WDF5',
#  'WSF2',
#  'WSF5',
#  'WT01',
#  'WT02',
#  'WT04',
#  'WT06',
#  'WT08'}

# %%
df_temp=df[df['datatype']=='TMAX']
df_temp['value']=df_temp['value']/10
df_temp['F']=df_temp['value']*9/5+32


df_temp
# Out:
# C:\Users\Dmitry\AppData\Local\Temp\ipykernel_31064\2953924998.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp['value']=df_temp['value']/10
# C:\Users\Dmitry\AppData\Local\Temp\ipykernel_31064\2953924998.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp['F']=df_temp['value']*9/5+32
#                     date datatype            station attributes  value      F
# 12   2022-01-01T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   25.6  78.08
# 31   2022-01-02T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   21.7  71.06
# 50   2022-01-03T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   15.0  59.00
# 69   2022-01-04T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400    7.8  46.04
# 87   2022-01-05T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   15.6  60.08
# 105  2022-01-06T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   16.7  62.06
# 123  2022-01-07T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400    9.4  48.92
# 141  2022-01-08T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400    6.7  44.06
# 159  2022-01-09T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   15.0  59.00
# 178  2022-01-10T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   11.1  51.98
# 196  2022-01-11T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400    8.3  46.94
# 214  2022-01-12T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   11.1  51.98
# 232  2022-01-13T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   12.2  53.96
# 250  2022-01-14T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   15.0  59.00
# 268  2022-01-15T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400    6.7  44.06
# 286  2022-01-16T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400    3.3  37.94
# 307  2022-01-17T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400    6.1  42.98
# 325  2022-01-18T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   10.0  50.00
# 343  2022-01-19T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   15.0  59.00
# 361  2022-01-20T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400    9.4  48.92
# 380  2022-01-21T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400    1.7  35.06
# 399  2022-01-22T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400    3.3  37.94
# 418  2022-01-23T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   10.6  51.08
# 436  2022-01-24T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   12.8  55.04
# 454  2022-01-25T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   16.7  62.06
# 472  2022-01-26T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400    8.9  48.02
# 490  2022-01-27T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400    7.8  46.04
# 508  2022-01-28T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400    8.9  48.02
# 527  2022-01-29T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400    3.9  39.02
# 546  2022-01-30T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   10.6  51.08
# 564  2022-01-31T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   14.4  57.92
# 582  2022-02-01T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   12.2  53.96
# 600  2022-02-02T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   13.3  55.94
# 619  2022-02-03T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   17.8  64.04
# 638  2022-02-04T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   18.9  66.02
# 657  2022-02-05T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400    8.3  46.94
# 675  2022-02-06T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400    7.8  46.04
# 693  2022-02-07T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400    5.6  42.08
# 712  2022-02-08T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   13.3  55.94
# 733  2022-02-09T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   15.0  59.00
# 752  2022-02-10T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   19.4  66.92
# 770  2022-02-11T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   20.6  69.08
# 788  2022-02-12T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   22.2  71.96
# 806  2022-02-13T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   11.1  51.98
# 824  2022-02-14T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   12.8  55.04
# 842  2022-02-15T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   12.8  55.04
# 860  2022-02-16T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   20.0  68.00
# 878  2022-02-17T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   23.3  73.94
# 898  2022-02-18T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   21.1  69.98
# 917  2022-02-19T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   16.1  60.98
# 935  2022-02-20T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   12.8  55.04
# 953  2022-02-21T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   17.2  62.96
# 972  2022-02-22T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   23.3  73.94
# 990  2022-02-23T00:00:00     TMAX  GHCND:USW00013881   ,,W,2400   18.3  64.94

# %%
alt.Chart(df_temp).mark_line().encode(
    x='date',
    y='F'
)
# Out:
# alt.Chart(...)
